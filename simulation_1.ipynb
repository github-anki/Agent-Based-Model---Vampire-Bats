# %% [markdown]
# # Figure 1

# %%
from agent.Vampire import Vampire 
from model.VampireModel import VampireModel 
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = VampireModel(max_iteration = 350, food_sharing = False)
model.run_model()

# %%
df = model.datacollector.get_model_vars_dataframe()

# %%
df.plot()

# %%
model = VampireModel(max_iteration = 350, food_sharing = True)
model.run_model()

# %%
df = model.datacollector.get_model_vars_dataframe()
df.plot()
