# %% [markdown]
# # Figure 2

# %%
from agent.Vampire import SimpleVampire, SmartVampire
from model.VampireModel import VampireModel 
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = VampireModel(max_iteration = 350, food_sharing = True, vampire_type = SmartVampire)
model.run_model()

df = model.datacollector.get_model_vars_dataframe()
df.plot()

# %%
model = VampireModel(max_iteration = 350, food_sharing = True, vampire_type = SimpleVampire)
model.run_model()

df = model.datacollector.get_model_vars_dataframe()
df.plot()
